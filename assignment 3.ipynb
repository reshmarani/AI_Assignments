# %%
import numpy as np
y = np.array([1,2,3,4])
j = np.array([5.5,6.6,6.9,7.7])
np.add(y,j)
# Out:
# array([ 6.5,  8.6,  9.9, 11.7])

# %%
import numpy as np
y = np.array([1,2,3,4])
j = np.array([5.5,6.6,6.9,7.7])
np.subtract(y,j)
# Out:
# array([-4.5, -4.6, -3.9, -3.7])

# %%
import numpy as np
y = np.array([1,2,3,4])
j = np.array([5.5,6.6,6.9,7.7])
np.multiply(y,j)
# Out:
# array([ 5.5, 13.2, 20.7, 30.8])

# %%
import numpy as np
y = np.array([1,2,3,4])
j = np.array([5.5,6.6,6.9,7.7])
np. divide(y,j)
# Out:
# array([0.18181818, 0.3030303 , 0.43478261, 0.51948052])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
np.sqrt(y)
# Out:
# array([[1.        , 1.41421356],
#        [1.73205081, 2.        ]])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
np.min(y,axis=0)
# Out:
# array([1, 2])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
np.min(y,axis=1)
# Out:
# array([1, 3])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
np.power( y,3)
# Out:
# array([[ 1,  8],
#        [27, 64]], dtype=int32)

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
j= np.array([[2,3],[3,6]])
np.multiply( y,j)
# Out:
# array([[ 2,  6],
#        [ 9, 24]])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
(np.max(y,axis=0))
# Out:
# array([3, 4])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
(np.max(y,axis=1))
# Out:
# array([2, 4])

# %%
import numpy as np
y = np.array([[1,2],(3,4)])
np.exp (y)
# Out:
# array([[ 2.71828183,  7.3890561 ],
#        [20.08553692, 54.59815003]])

# %%
import numpy as np
y= np.array([[1,2],(3,4)])
y.mean()
# Out:
# 2.5

# %%
import numpy as np
y= np.array([[1,2],(3,4)])
y.std()
# Out:
# 1.118033988749895

# %%
import numpy as np
y= np.array([[1,2],(3,4)])
np.median(y)
# Out:
# 2.5
